# %% [markdown]
# ### Pyschomotor Vigilance Test (PVT)

# %% [markdown]
# ### Subjective Measures

# %% [markdown]
# #### Visual Analogue Scale (VAS)

# %% [markdown]
# #### Stanford Sleepiness Scale (SSS)

# %% [markdown]
# ### Nasa-TLX
